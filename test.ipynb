# %%
! pip install transformers torch
! pip install langchain_community
# Out:
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.3 MB 9.0 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/11.3 MB 11.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.7/11.3 MB 9.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.3/11.3 MB 8.1 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.3 MB 7.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.4/11.3 MB 7.0 MB/s eta 0:00:01
#    ------------------------------ --------- 8.7/11.3 MB 6.7 MB/s eta 0:00:01
#    -------------------------------- ------- 9.2/11.3 MB 5.7 MB/s eta 0:00:01
#    --------------------------------- ------ 9.4/11.3 MB 5.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.0/11.3 MB 4.9 MB/s eta 0:00:01
# ...

# %%
! pip install huggingface_hub requests
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install --upgrade huggingface_hub
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from secret_key import hugface_key
import os
os.environ["HUGGING_FACE_API_KEY"] = hugface_key

# %%
from secret_key import hugface_key
from huggingface_hub import InferenceClient

client = InferenceClient(token=hugface_key)

response = client.post(
    model="google/flan-t5-base",
    inputs="I want to open a restaurant for Indian food. Suggest a fancy name for this.",
    parameters={"max_new_tokens": 50}
)

print(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 6
#       2 from huggingface_hub import InferenceClient
#       4 client = InferenceClient(token=hugface_key)
# ----> 6 response = client.post(
#       7     model="google/flan-t5-base",
#       8     inputs="I want to open a restaurant for Indian food. Suggest a fancy name for this.",
#       9     parameters={"max_new_tokens": 50}
#      10 )
#      12 print(response)
#
# AttributeError: 'InferenceClient' object has no attribute 'post'

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
print(classifier("I love using Hugging Face!"))
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# e:\GEN-AI\env\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ASUS\.cache\huggingface\hub\models--distilbert--distilbert-base-uncased-finetuned-sst-2-english. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...

# %%
! pip install huggingface_hub
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.llms import HuggingFaceHub

# Pick a model (chat or text generation)
# Example: Mistral instruct model
llm = HuggingFaceHub(
    repo_id="mistralai/Mixtral-8x7B-Instruct-v0.1", 
    model_kwargs={"temperature":0.6, "max_new_tokens":200}
)

# Send prompt
name = llm("I want to open a restaurant for Indian food. Suggest a fancy name for this.")
print(name)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[14], line 5
#       1 from langchain_community.llms import HuggingFaceHub
#       3 # Pick a model (chat or text generation)
#       4 # Example: Mistral instruct model
# ----> 5 llm = HuggingFaceHub(
#       6     repo_id="mistralai/Mixtral-8x7B-Instruct-v0.1",
#       7     model_kwargs={"temperature":0.6, "max_new_tokens":200}
#       8 )
#      10 # Send prompt
#      11 name = llm("I want to open a restaurant for Indian food. Suggest a fancy name for this.")
#
# File e:\GEN-AI\env\Lib\site-packages\langchain_core\_api\deprecation.py:223, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     221     warned = True
#     222     emit_warning()
# --> 223 return wrapped(self, *args, **kwargs)
#
# ...
